# %% [markdown]
# # Pipeline

# %%
# Importing libraries
import numpy as np
import pandas as pd
import math
import random

# %%
# Extracting data from three different .csv sources

# Here we read employees.csv file and store in emp as a dataframe
emp = pd.read_csv('/home/sage_gaurab/chained/code_world/ds_py/data_src/employees.csv')

# Here we read departments.csv file and store in dept as a dataframe
dept = pd.read_csv('/home/sage_gaurab/chained/code_world/ds_py/data_src/departments.csv')

# Here we read bonus.csv file and store in bonus as a dataframe
bonus = pd.read_csv('/home/sage_gaurab/chained/code_world/ds_py/data_src/bonus.csv')

# %%
# Funciton for producing full_name column
def add_full_name(df):
    return df.assign(full_name = df['first_name'] + ' ' + df['last_name'])

# Funciton to replace null salary value
def replace_null_salary(df, method = 'mean'):
    if method == 'mean':
        fill_value = df['salary'].mean().round(0)
    elif method == 'dept_mean':
        fill_value = df.groupby('department_id')['salary'].transform('mean').round(0)
    elif method == 'median':
        fill_value = df['salary'].median().round(0)
    return df.assign(salary = df['salary'].fillna(fill_value))

# Function to join all three table
def joined_df(df, df_dept, df_bonus):
    return(
        df.merge(df_dept, on = 'department_id', how = 'left').
           merge(df_bonus, on = 'employee_id',  how = 'left')
    )
# Function to fill null bonus rows                                                                  
def replace_null_bonus(df):
    return df.assign(bonus_amount = df['bonus_amount'].fillna(0))
    
# Function to calculate annual salary
def add_annual_salary(df):
    return df.assign(annual_salary = df['salary']*12) # 1st chal

# Function to calculate perfomance bonus
def add_performance_bonus(df):
    return df.assign(performance_bonus = (df['bonus_amount'] * df['performance_score']/100).round(0))
    

# _________________________________________ Analysing function _________________________________________________________

def average_salary(df):
    return df.assign(average_salary = df['salary'].mean())

def total_salary(df):
    return df.assign(total_salary = df['salary'].sum())

# %%
cleaned_df = (
    emp.pipe(add_full_name)
        .pipe(replace_null_salary, method = 'dept_mean')
        .pipe(joined_df, dept, bonus)
        .pipe(replace_null_bonus)
        .pipe(add_annual_salary)
        .pipe(add_performance_bonus)
        .pipe(average_salary)
        .pipe(total_salary)
)
cleaned_df[['employee_id','full_name','salary','annual_salary','department_name','bonus_amount','performance_score', 'performance_bonus']].sample(5)
# Out:
#     employee_id        full_name   salary  annual_salary department_name  \
# 9            10    Olivia Thomas  78000.0       936000.0       Marketing
# 2             3     Mike Johnson  65000.0       780000.0           Sales
# 15           16  Isabella Garcia  82500.0       990000.0              IT
# 19           20         John Doe  60000.0       720000.0           Sales
# 0             1         John Doe  60000.0       720000.0           Sales
#
#     bonus_amount  performance_score  performance_bonus
# 9            0.0                 96                0.0
# 2            0.0                 78                0.0
# 15           0.0                 93                0.0
# 19           0.0                 85                0.0
# 0         5000.0                 85             4250.0

# %% [markdown]
# ### PipelineFactory: Parameterized Reusable Pipeline
# ----

# %%
def outer_func(method = 'mean', join_choice = True, bonus_fill = False, performance_bonus = False):
    
    def pipeline(df, df_dept = None, df_bonus = None):
        result = df.pipe(add_full_name).pipe(replace_null_salary, method = method)
        if join_choice:
            result = result.pipe(joined_df, df_dept, df_bonus)
            
        if bonus_fill and join_choice:
            result = result.pipe(replace_null_bonus)
            
        if performance_bonus and join_choice:
            result = result.pipe(add_performance_bonus)
        return result
        
    return pipeline

# %%
# generating piple using pipline factory 
result_pipeline =  outer_func(method = 'mean', join_choice = False, bonus_fill = True, performance_bonus = True)

# pipline which transform data according to passed arguments
result_pipeline(emp, df_dept = dept, df_bonus = bonus).sample(5)
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 13           14        Ava    Martin             10  63000.0  2021-04-25
# 17           18  Charlotte  Robinson             20  76000.0  2021-08-25
# 3             4      Emily     Brown             30  80000.0  2020-04-05
# 8             9      James  Anderson             40  58000.0  2020-09-25
# 7             8     Sophia    Taylor             10  62000.0  2020-08-30
#
#         city  performance_score           full_name
# 13   Atlanta                 80          Ava Martin
# 17   Orlando                 94  Charlotte Robinson
# 3    Houston                 95         Emily Brown
# 8   San Jose                 72      James Anderson
# 7     Dallas                 91       Sophia Taylor

# %%
result_pipeline2 = outer_func(method = 'mean', join_choice = True, bonus_fill = True, performance_bonus = True)
result_pipeline2(emp, df_dept = dept, df_bonus = bonus).head(5)
# Out:
#    employee_id first_name last_name  department_id   salary   hire_date  \
# 0            1       John       Doe             10  60000.0  2020-01-15
# 1            2       Jane     Smith             20  75000.0  2020-02-20
# 2            3       Mike   Johnson             10  65000.0  2020-03-10
# 3            4      Emily     Brown             30  80000.0  2020-04-05
# 4            5      David     Davis             40  69667.0  2020-05-12
#
#           city  performance_score     full_name department_name     location  \
# 0     New York                 85      John Doe           Sales     New York
# 1  Los Angeles                 92    Jane Smith       Marketing  Los Angeles
# 2      Chicago                 78  Mike Johnson           Sales     New York
# 3      Houston                 95   Emily Brown              IT      Chicago
# 4      Phoenix                 88   David Davis              HR      Houston
#
#     budget  bonus_amount  bonus_date  performance_bonus
# 0   500000        5000.0  2023-01-01             4250.0
# 1   800000        8000.0  2023-01-01             7360.0
# 2   500000           0.0         NaN                0.0
# 3  1200000       10000.0  2023-01-01             9500.0
# 4   400000           0.0         NaN                0.0

# %%
emp.sample()
# Out:
#    employee_id first_name last_name  department_id  salary   hire_date  \
# 4            5      David     Davis             40     NaN  2020-05-12
#
#       city  performance_score
# 4  Phoenix                 88

# %%
dept.sample()
# Out:
#    department_id department_name location  budget
# 3             40              HR  Houston  400000

# %%
bonus.sample()
# Out:
#    employee_id  bonus_amount  bonus_date
# 6           13          7500  2023-01-01

# %%
# 3rd chall
def outer_f():
    def inner_f(df):
        result = df.pipe(add_full_name).pipe(replace_null_salary, method = 'mean').pipe(joined_df, dept, bonus)
        return result
    return inner_f

# %%
pipeline = outer_f()
pipeline(emp).sample(3)
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 11           12       Emma     White             30  82000.0  2021-02-15
# 12           13    Michael    Harris             20  74000.0  2021-03-20
# 10           11    William   Jackson             10  61000.0  2021-01-10
#
#        city  performance_score        full_name department_name     location  \
# 11   Denver                 89       Emma White              IT      Chicago
# 12    Miami                 87   Michael Harris       Marketing  Los Angeles
# 10  Seattle                 83  William Jackson           Sales     New York
#
#      budget  bonus_amount  bonus_date
# 11  1200000           NaN         NaN
# 12   800000        7500.0  2023-01-01
# 10   500000        5500.0  2023-01-01

# %%
# 4th chall
def outer_4f(method = 'mean'):
    def inner_4f(df):
        result = df.pipe(add_full_name).pipe(replace_null_salary, method = method).pipe(joined_df, dept, bonus)
        return result
    return inner_4f

# %%
x = outer_4f(method = 'dept_mean')
x(emp).sample(5)
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 17           18  Charlotte  Robinson             20  76000.0  2021-08-25
# 14           15     Daniel  Thompson             40  56000.0  2021-05-30
# 2             3       Mike   Johnson             10  65000.0  2020-03-10
# 6             7     Robert     Moore             30  85000.0  2020-07-22
# 10           11    William   Jackson             10  61000.0  2021-01-10
#
#            city  performance_score           full_name department_name  \
# 17      Orlando                 94  Charlotte Robinson       Marketing
# 14       Boston                 75     Daniel Thompson              HR
# 2       Chicago                 78        Mike Johnson           Sales
# 6   San Antonio                 79        Robert Moore              IT
# 10      Seattle                 83     William Jackson           Sales
#
#        location   budget  bonus_amount  bonus_date
# 17  Los Angeles   800000        9000.0  2023-01-01
# 14      Houston   400000        4000.0  2023-01-01
# 2      New York   500000           NaN         NaN
# 6       Chicago  1200000           NaN         NaN
# 10     New York   500000        5500.0  2023-01-01

# %%
def outer_5f(method = 'mean', include_join = True):
    def inner_5f(df):
        result = df.pipe(add_full_name).pipe(replace_null_salary, method = method)
        if include_join:
            result = result.pipe(joined_df, dept, bonus).pipe(replace_null_bonus)
        return result
    return inner_5f

# %%
# Instance 1
quick_analysis = outer_5f(method = 'mean', include_join = False)
quick_analysis(emp).sample()
# Out:
#    employee_id first_name last_name  department_id   salary   hire_date  \
# 4            5      David     Davis             40  69667.0  2020-05-12
#
#       city  performance_score    full_name
# 4  Phoenix                 88  David Davis

# %%
# Instance 2
dept_analysis = outer_5f(method = 'dept_mean', include_join = True)
dept_analysis(emp).sample()
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 10           11    William   Jackson             10  61000.0  2021-01-10
#
#        city  performance_score        full_name department_name  location  \
# 10  Seattle                 83  William Jackson           Sales  New York
#
#     budget  bonus_amount  bonus_date
# 10  500000        5500.0  2023-01-01

# %%
# Instance 3
custom_analysis = outer_5f(method = 'median', include_join = True)
custom_analysis(emp).sample()
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 15           16   Isabella    Garcia             30  68500.0  2021-06-15
#
#         city  performance_score        full_name department_name location  \
# 15  Portland                 93  Isabella Garcia              IT  Chicago
#
#      budget  bonus_amount bonus_date
# 15  1200000           0.0        NaN

# %%
def outer_func(method = 'mean', join_choice = True, bonus_fill = False, performance_bonus = False, analyze = True):
    
    def pipeline(df, df_dept = None, df_bonus = None):
        result = df.pipe(add_full_name).pipe(replace_null_salary, method = method)
        if join_choice:
            result = result.pipe(joined_df, df_dept, df_bonus)
            
        if bonus_fill and join_choice:
            result = result.pipe(replace_null_bonus)
            
        if performance_bonus and join_choice:
            result = result.pipe(add_performance_bonus)
            
        if analyze:
            result = result.pipe(average_salary).pipe(total_salary)
            
        return result
        
    return pipeline

# %%
test = outer_func(method = 'mean', join_choice = True, bonus_fill = True, performance_bonus = True, analyze = True)
test(emp, dept, bonus).sample(5)
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 1             2       Jane     Smith             20  75000.0  2020-02-20
# 3             4      Emily     Brown             30  80000.0  2020-04-05
# 6             7     Robert     Moore             30  85000.0  2020-07-22
# 12           13    Michael    Harris             20  74000.0  2021-03-20
# 8             9      James  Anderson             40  58000.0  2020-09-25
#
#            city  performance_score       full_name department_name  \
# 1   Los Angeles                 92      Jane Smith       Marketing
# 3       Houston                 95     Emily Brown              IT
# 6   San Antonio                 79    Robert Moore              IT
# 12        Miami                 87  Michael Harris       Marketing
# 8      San Jose                 72  James Anderson              HR
#
#        location   budget  bonus_amount  bonus_date  performance_bonus  \
# 1   Los Angeles   800000        8000.0  2023-01-01             7360.0
# 3       Chicago  1200000       10000.0  2023-01-01             9500.0
# 6       Chicago  1200000           0.0         NaN                0.0
# 12  Los Angeles   800000        7500.0  2023-01-01             6525.0
# 8       Houston   400000           0.0         NaN                0.0
#
#     average_salary  total_salary
# 1          69666.7     1393334.0
# 3          69666.7     1393334.0
# 6          69666.7     1393334.0
# 12         69666.7     1393334.0
# 8          69666.7     1393334.0

# %%
# config takes dictionary as a argument
# config got key : value pairs of 
# function and its arguments

def pipeline_factory(config):
    steps = [add_full_name] # first steps in the pipeline

    if config.get('method'): # if nothing is passed in the dictionary
            steps.append(lambda df: replace_null_salary(df, method=config['method']))

    if config.get('join_choice'):
            steps.append(lambda df: joined_df(df, config['df_dept'], config['df_bonus']))

    if config.get('bonus_fill') and config.get('join_choice'):
            steps.append(replace_null_bonus)

    def pipeline(df):
        for step in steps:
            df = df.pipe(step)
        return df
    return pipeline

# %%
pipe_fac_dic = {
    'method' : 'mean',
    'join_choice' : True,
    'bonus_fill' : True
}

# %%
pipeline_factory(pipe_fac_dic)
# Out:
# <function __main__.pipeline_factory.<locals>.pipeline(df)>

# %%
data_pipeline = pipeline(emp)

# %%
data_pipeline
# Out:
#     employee_id first_name last_name  department_id   salary   hire_date  \
# 0             1       John       Doe             10  60000.0  2020-01-15
# 1             2       Jane     Smith             20  75000.0  2020-02-20
# 2             3       Mike   Johnson             10  65000.0  2020-03-10
# 3             4      Emily     Brown             30  80000.0  2020-04-05
# 4             5      David     Davis             40  69667.0  2020-05-12
# 5             6      Laura    Wilson             20  72000.0  2020-06-18
# 6             7     Robert     Moore             30  85000.0  2020-07-22
# 7             8     Sophia    Taylor             10  62000.0  2020-08-30
# 8             9      James  Anderson             40  58000.0  2020-09-25
# 9            10     Olivia    Thomas             20  78000.0  2020-10-15
# 10           11    William   Jackson             10  61000.0  2021-01-10
# 11           12       Emma     White             30  82000.0  2021-02-15
# 12           13    Michael    Harris             20  74000.0  2021-03-20
# 13           14        Ava    Martin             10  63000.0  2021-04-25
# 14           15     Daniel  Thompson             40  56000.0  2021-05-30
# 15           16   Isabella    Garcia             30  69667.0  2021-06-15
# 16           17    Matthew  Martinez             10  64000.0  2021-07-20
# 17           18  Charlotte  Robinson             20  76000.0  2021-08-25
# 18           19     Joseph     Clark             30  83000.0  2021-09-30
# 19           20       John       Doe             10  60000.0  2022-01-15
#
#             city  performance_score           full_name department_name  \
# 0       New York                 85            John Doe           Sales
# 1    Los Angeles                 92          Jane Smith       Marketing
# 2        Chicago                 78        Mike Johnson           Sales
# 3        Houston                 95         Emily Brown              IT
# 4        Phoenix                 88         David Davis              HR
# 5   Philadelphia                 90        Laura Wilson       Marketing
# 6    San Antonio                 79        Robert Moore              IT
# 7         Dallas                 91       Sophia Taylor           Sales
# 8       San Jose                 72      James Anderson              HR
# 9         Austin                 96       Olivia Thomas       Marketing
# 10       Seattle                 83     William Jackson           Sales
# 11        Denver                 89          Emma White              IT
# 12         Miami                 87      Michael Harris       Marketing
# 13       Atlanta                 80          Ava Martin           Sales
# 14        Boston                 75     Daniel Thompson              HR
# 15      Portland                 93     Isabella Garcia              IT
# 16     Las Vegas                 81    Matthew Martinez           Sales
# 17       Orlando                 94  Charlotte Robinson       Marketing
# 18       Detroit                 86        Joseph Clark              IT
# 19      New York                 85            John Doe           Sales
#
#        location   budget  bonus_amount  bonus_date
# 0      New York   500000        5000.0  2023-01-01
# 1   Los Angeles   800000        8000.0  2023-01-01
# 2      New York   500000           NaN         NaN
# 3       Chicago  1200000       10000.0  2023-01-01
# 4       Houston   400000           NaN         NaN
# 5   Los Angeles   800000        7000.0  2023-01-01
# 6       Chicago  1200000           NaN         NaN
# 7      New York   500000        6000.0  2023-01-01
# 8       Houston   400000           NaN         NaN
# 9   Los Angeles   800000           NaN         NaN
# 10     New York   500000        5500.0  2023-01-01
# 11      Chicago  1200000           NaN         NaN
# 12  Los Angeles   800000        7500.0  2023-01-01
# 13     New York   500000           NaN         NaN
# 14      Houston   400000        4000.0  2023-01-01
# 15      Chicago  1200000           NaN         NaN
# 16     New York   500000           NaN         NaN
# 17  Los Angeles   800000        9000.0  2023-01-01
# 18      Chicago  1200000           NaN         NaN
# 19     New York   500000           NaN         NaN
